# %%
#Entrar a una página y descargar un archivo utilizando Selenium

#Importar librerías
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
#Webdriver
driver = webdriver.Chrome(executable_path="C:/chromedriver.exe")
driver.maximize_window()
# Out:
# C:\Users\claud\AppData\Local\Temp\ipykernel_21128\3686882268.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/chromedriver.exe")

# %%
#Establecer directorio de descarga
os.chdir("C:/Users/claud/Downloads")

# %%
url="https://www.inegi.org.mx/app/tabulados/default.html?nc=625&idrt=18&opc=t"

# %%
driver.get(url)

# %%
#Descargar archivo csv
driver.find_element(By.ID, 'aCsv').click()
time.sleep(1)

# %%
#Leer archivo csv
df = pd.read_csv('Tabulado.csv', encoding='utf-8')
df
# Out:
#                                               Periodo  Aguascalientes  \
# 0                                                2019             NaN
# 1                                                   I        3.425260
# 2                                                  II        3.720254
# 3                                                 III        3.535829
# 4                                                  IV        3.393098
# 5                                                2020             NaN
# 6                                                   I        3.511716
# 7                                                  II        4.601252
# 8                                                 III        4.819217
# 9                                                  IV        5.269827
# 10                                               2021             NaN
# 11                                                  I        3.812915
# ...
